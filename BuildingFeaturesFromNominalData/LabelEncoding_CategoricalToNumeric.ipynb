# %%
from sklearn import preprocessing

import pandas as pd
import numpy as np

# %%
num_encoder = preprocessing.LabelEncoder()

# %%
num_encoder.fit([50,20,60,60])
# Out:
# LabelEncoder()

# %%
num_encoder.classes_
# Out:
# array([20, 50, 60])

# %%
num_encoder.transform([50,20,60,60])
# Out:
# array([1, 0, 2, 2], dtype=int64)

# %%
num_encoder.inverse_transform([1,0,2,2])
# Out:
# array([50, 20, 60, 60])

# %%
string_encoder = preprocessing.LabelEncoder()

# %%
string_encoder.fit(['cloudy','sunny','rainy','windy','cloudy'])
# Out:
# LabelEncoder()

# %%
string_encoder.classes_
# Out:
# array(['cloudy', 'rainy', 'sunny', 'windy'], dtype='<U6')

# %%
string_encoder.transform(['cloudy', 'rainy', 'sunny', 'windy'])
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
data = pd.read_csv('datasets/exams.csv')

data
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B          associate's degree      standard
# 1   female        group B                 high school  free/reduced
# 2   female        group D            some high school  free/reduced
# 3     male        group A          associate's degree  free/reduced
# 4   female        group E            some high school      standard
# ..     ...            ...                         ...           ...
# 95    male        group A          associate's degree      standard
# 96  female        group E                some college      standard
# 97    male        group B           bachelor's degree  free/reduced
# 98    male        group B          associate's degree      standard
# 99    male        group E            some high school  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 0                     none          55             61             58
# 1                     none          59             70             66
# 2                     none          17             18             26
# 3                     none          63             61             58
# 4                     none          70             80             79
# ..                     ...         ...            ...            ...
# 95                    none          80             81             73
# 96                    none          81             86             84
# 97                    none          67             74             72
# 98               completed          67             62             64
# 99                    none          67             59             57
#
# [100 rows x 8 columns]

# %%
data_encoder = preprocessing.LabelEncoder()

# %%
# this encodes all the colums at the same time
gender_le = data.apply(data_encoder.fit_transform)

# %%
gender_le
# Out:
#     gender  race/ethnicity  parental level of education  lunch  \
# 0        0               1                            0      1
# 1        0               1                            2      0
# 2        0               3                            5      0
# 3        1               0                            0      0
# 4        0               4                            5      1
# ..     ...             ...                          ...    ...
# 95       1               0                            0      1
# 96       0               4                            4      1
# 97       1               1                            1      0
# 98       1               1                            0      1
# 99       1               4                            5      0
#
#     test preparation course  math score  reading score  writing score
# 0                         1          14             17             16
# 1                         1          18             26             23
# 2                         1           0              0              0
# 3                         1          22             17             16
# 4                         1          29             36             35
# ..                      ...         ...            ...            ...
# 95                        1          36             37             29
# 96                        1          37             41             39
# 97                        1          26             30             28
# 98                        0          26             18             21
# 99                        1          26             16             15
#
# [100 rows x 8 columns]

# %%
data['gender'] = data_encoder.fit_transform(data.gender)

# %%
data
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0        0        group B          associate's degree      standard
# 1        0        group B                 high school  free/reduced
# 2        0        group D            some high school  free/reduced
# 3        1        group A          associate's degree  free/reduced
# 4        0        group E            some high school      standard
# ..     ...            ...                         ...           ...
# 95       1        group A          associate's degree      standard
# 96       0        group E                some college      standard
# 97       1        group B           bachelor's degree  free/reduced
# 98       1        group B          associate's degree      standard
# 99       1        group E            some high school  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 0                     none          55             61             58
# 1                     none          59             70             66
# 2                     none          17             18             26
# 3                     none          63             61             58
# 4                     none          70             80             79
# ..                     ...         ...            ...            ...
# 95                    none          80             81             73
# 96                    none          81             86             84
# 97                    none          67             74             72
# 98               completed          67             62             64
# 99                    none          67             59             57
#
# [100 rows x 8 columns]

# %%
# !pip install pytesseract

# %%
# !pip install pillow

# %%
from PIL import Image, ImageFilter
import pytesseract

import numpy as np
import matplotlib.pyplot as plt

from skimage import color
import cv2
import io

# %%
quote_img = Image.open('datasets/motivational-quote.jpg')

# %%
quote_img.format, quote_img.mode, quote_img.size
# Out:
# ('JPEG', 'RGB', (5835, 3761))

# %%
plt.figure(figsize=(12,6))
plt.title('Original Image')
plt.imshow(quote_img)

plt.show()

# %%
pytesseract.pytesseract.tesseract_cmd = r'C://Users//NEHA//Downloads'

# %%
text = pytesseract.image_to_string(quote_img, lang ='eng')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-10-243afc5cc913> in <module>
# ----> 1 text = pytesseract.image_to_string(quote_img, lang ='eng')
#
# ~\Anaconda3\lib\site-packages\pytesseract\pytesseract.py in image_to_string(image, lang, config, nice, output_type, timeout)
#     356         Output.DICT: lambda: {'text': run_and_get_output(*args)},
#     357         Output.STRING: lambda: run_and_get_output(*args),
# --> 358     }[output_type]()
#     359
#     360
#
# ~\Anaconda3\lib\site-packages\pytesseract\pytesseract.py in <lambda>()
#     355         Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     356         Output.DICT: lambda: {'text': run_and_get_output(*args)},
# --> 357         Output.STRING: lambda: run_and_get_output(*args),
#     358     }[output_type]()
#     359
#
# ...

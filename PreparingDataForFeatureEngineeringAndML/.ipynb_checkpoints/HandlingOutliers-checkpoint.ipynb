# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
mall_customer_info = pd.read_csv('datasets/mall_customers.csv')

# %%
mall_customer_info.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
mall_customer_info.shape
# Out:
# (200, 5)

# %%
mall_customer_info.isnull().any()
# Out:
# CustomerID                False
# Genre                     False
# Age                       False
# Annual Income (k$)        False
# Spending Score (1-100)    False
# dtype: bool

# %%
mall_customer_info.nunique()
# Out:
# CustomerID                200
# Genre                       2
# Age                        51
# Annual Income (k$)         64
# Spending Score (1-100)     84
# dtype: int64

# %%
mall_customer_info["Annual Income (k$)"].plot.hist(bins=10, figsize=(10,8))

# %%
mall_customer_info.plot.scatter(x='Age',
                               y="Annual Income (k$)",
                               c='DarkBlue',
                               figsize=(10,8));

# %%
mall_customer_info.plot.scatter(x='Age',
                               y="Annual Income (k$)",
                               c='Spending Score (1-100)',
                               colormap='viridis',
                               figsize=(10,8));

# %%
boxplot = mall_customer_info.boxplot(grid=False, rot=45, figsize=(10,7))

# %%
# here the circle is the outlier in the annual income column
boxplot = mall_customer_info.boxplot(grid=False, fontsize=15,column="Annual Income (k$)", figsize=(10,8))

# %%
#finding the outliers
mall_customer_info.loc[mall_customer_info["Annual Income (k$)"]>125]
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
# finding 25th and 75th percentile of our annual income
Q1 = mall_customer_info["Annual Income (k$)"].quantile(0.25)
Q3 = mall_customer_info["Annual Income (k$)"].quantile(0.75)
Q1, Q3
# Out:
# (41.5, 78.0)

# %%
#finding inter quartile range
IQR= Q3-Q1
IQR
# Out:
# 36.5

# %%
mall_customer_info['Annual_Income_Outlier']=False

# %%
#defining my outliers....i.e. any income above 96.25 are our outliers
Q1 + 1.5*IQR
# Out:
# 96.25

# %%
for index, row in mall_customer_info.iterrows():
    if row["Annual Income (k$)"]>(Q1 + 1.5*IQR):
        mall_customer_info.at[index, 'Annual_Income_Outlier']=True

# %%
mall_customer_info['Annual_Income_Outlier'].sum()
# Out:
# 20

# %%
non_outliers = mall_customer_info.loc[mall_customer_info['Annual_Income_Outlier']==False]

# %%
non_outliers.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
#    Annual_Income_Outlier
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False

# %%
mean = non_outliers['Annual Income (k$)'].mean()
mean
# Out:
# 55.1

# %%
for index, row in mall_customer_info.iterrows():
    if row["Annual_Income_Outlier"]==True:
        mall_customer_info.at[index, "Annual Income (k$)"] = mean

# %%
mall_customer_info.sample(5)
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 95           96    Male   24                  60                      52
# 37           38  Female   30                  34                      73
# 142         143  Female   28                  76                      40
# 123         124    Male   39                  69                      91
# 67           68  Female   68                  48                      48
#
#      Annual_Income_Outlier
# 95                   False
# 37                   False
# 142                  False
# 123                  False
# 67                   False

# %%
# the outliers are replaced by the mean value
boxplot = mall_customer_info.boxplot(grid=False, fontsize=15,column="Annual Income (k$)", figsize=(10,8))

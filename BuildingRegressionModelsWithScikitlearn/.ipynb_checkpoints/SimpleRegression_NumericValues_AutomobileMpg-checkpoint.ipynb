# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
automobile_df = pd.read_csv('datasets/auto-mpg-processed.csv')
automobile_df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  age
# 0  32.0          4         144.0          96    2665          13.9   38
# 1  18.0          6         232.0         100    2789          15.0   47
# 2  29.0          4          97.0          75    2171          16.0   45
# 3  13.0          8         400.0         170    4746          12.0   49
# 4  16.5          8         350.0         180    4380          12.1   44

# %%
from sklearn.model_selection import train_test_split

x = automobile_df[['horsepower']]
y = automobile_df['mpg']

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
x_train.sample(5)
# Out:
#      horsepower
# 164          72
# 177          88
# 356          79
# 358         100
# 354         150

# %%
from sklearn.linear_model import LinearRegression

linear_model = LinearRegression(normalize=True).fit(x_train, y_train)

# %%
print('Training Score: ', linear_model.score(x_train, y_train))
# Out:
# Training Score:  0.6276399891310848

# %%
y_pred = linear_model.predict(x_test)

# %%
from sklearn.metrics import r2_score

print('Testing Score: ', r2_score(y_test, y_pred))
# Out:
# Testing Score:  0.49161326744917055

# %%
fig, ax = plt.subplots(figsize=(12,8))

plt.scatter(x_test, y_test)
plt.plot(x_test, y_pred, color='r')

plt.xlabel('Horsepower')
plt.ylabel('mpg')

plt.show()

# %%
x = automobile_df[['age']]
y = automobile_df['mpg']

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

linear_model = LinearRegression(normalize=True).fit(x_train, y_train)

print('Training Score: ', linear_model.score(x_train, y_train))

y_pred = linear_model.predict(x_test)
print('Testing Score: ', r2_score(y_test, y_pred))
# Out:
# Training Score:  0.32858710912592626
# Testing Score:  0.3651097922269394

# %%
fig, ax = plt.subplots(figsize=(12,8))

plt.scatter(x_test, y_test)
plt.plot(x_test, y_pred, color='r')

plt.xlabel('Age')
plt.ylabel('mpg')

plt.show()

# %% [markdown]
# Now we will use multiple features to train our model

# %%
x = automobile_df[['displacement', 'horsepower', 'weight']]
y = automobile_df['mpg']

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
linear_model = LinearRegression(normalize=True).fit(x_train, y_train)

print('Training Score: ', linear_model.score(x_train, y_train))

y_pred = linear_model.predict(x_test)
print('Testing Score: ', r2_score(y_test, y_pred))
# Out:
# Training Score:  0.7027637664553301
# Testing Score:  0.7164810476066865

# %%
fig, ax = plt.subplots(figsize=(20,10))

plt.plot(y_pred, label='Predicted')
plt.plot(y_test.values, label='Actual')

plt.ylabel('mpg')

plt.legend()
plt.show()

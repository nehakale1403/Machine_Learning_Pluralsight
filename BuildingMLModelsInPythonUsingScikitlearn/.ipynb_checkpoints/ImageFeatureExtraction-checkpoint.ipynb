# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\neha\anaconda3\lib\site-packages (4.4.0.42)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\neha\anaconda3\lib\site-packages (from opencv-python) (1.19.1)

# %%
import cv2

# %%
imagePath = 'datasets/dog.jpg'
image = cv2.imread('datasets/dog.jpg')

# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt

plt.imshow(image)

# %%
image.shape
# Out:
# (500, 750, 3)

# %%
image
# Out:
# array([[[240, 245, 248],
#         [240, 245, 248],
#         [240, 245, 248],
#         ...,
#         [233, 245, 251],
#         [233, 245, 251],
#         [233, 245, 251]],
#
#        [[240, 245, 248],
#         [240, 245, 248],
#         [240, 245, 248],
#         ...,
#         [233, 245, 251],
#         [233, 245, 251],
#         [233, 245, 251]],
#
#        [[240, 245, 248],
#         [240, 245, 248],
#         [240, 245, 248],
#         ...,
#         [233, 245, 251],
#         [233, 245, 251],
#         [233, 245, 251]],
#
#        ...,
#
#        [[143, 168, 194],
#         [143, 168, 194],
#         [142, 167, 193],
#         ...,
#         [ 95, 142, 109],
#         [ 93, 144, 107],
#         [ 93, 144, 107]],
#
#        [[141, 166, 192],
#         [141, 166, 192],
#         [141, 166, 192],
#         ...,
#         [ 93, 140, 107],
#         [ 91, 142, 105],
#         [ 90, 141, 104]],
#
#        [[139, 164, 190],
#         [140, 165, 191],
#         [140, 165, 191],
#         ...,
#         [ 92, 139, 106],
#         [ 89, 140, 103],
#         [ 89, 140, 103]]], dtype=uint8)

# %%
# rgb for the first pixel
image[0][0]
# Out:
# array([240, 245, 248], dtype=uint8)

# %%
size = (32, 32)
resized_image_feature_vector = cv2.resize(image, size)

# %%
plt.imshow(resized_image_feature_vector)

# %%
resized_image_feature_vector.shape
# Out:
# (32, 32, 3)

# %%
resized_image_feature_vector
# Out:
# array([[[242, 247, 250],
#         [242, 247, 250],
#         [243, 248, 250],
#         ...,
#         [237, 248, 252],
#         [233, 248, 251],
#         [227, 246, 251]],
#
#        [[244, 248, 249],
#         [244, 248, 249],
#         [246, 250, 251],
#         ...,
#         [221, 246, 250],
#         [219, 246, 250],
#         [214, 245, 248]],
#
#        [[244, 249, 252],
#         [245, 250, 253],
#         [244, 249, 252],
#         ...,
#         [216, 245, 249],
#         [217, 246, 250],
#         [214, 245, 248]],
#
#        ...,
#
#        [[188, 204, 218],
#         [153, 178, 204],
#         [135, 162, 188],
#         ...,
#         [ 82, 127,  88],
#         [ 94, 145, 109],
#         [ 92, 138, 102]],
#
#        [[170, 192, 210],
#         [147, 175, 199],
#         [126, 153, 180],
#         ...,
#         [ 91, 148, 110],
#         [ 93, 140, 101],
#         [ 99, 147, 111]],
#
#        [[141, 169, 193],
#         [131, 162, 185],
#         [122, 150, 178],
#         ...,
#         [ 87, 146, 105],
#         [ 88, 141, 101],
#         [ 91, 139, 102]]], dtype=uint8)

# %%
resized_flattened_image_feature_vector = resized_image_feature_vector.flatten()

# %%
resized_flattened_image_feature_vector
# Out:
# array([242, 247, 250, ...,  91, 139, 102], dtype=uint8)

# %%
len(resized_flattened_image_feature_vector)
# Out:
# 3072

# %%
image_grayscale = cv2.imread(imagePath, cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(image_grayscale)

# %%
image_grayscale.shape
# Out:
# (500, 750)

# %%
image_grayscale
# Out:
# array([[245, 245, 245, ..., 245, 245, 245],
#        [245, 245, 245, ..., 245, 245, 245],
#        [245, 245, 245, ..., 245, 245, 245],
#        ...,
#        [173, 173, 172, ..., 127, 127, 127],
#        [171, 171, 171, ..., 125, 125, 124],
#        [169, 170, 170, ..., 124, 123, 123]], dtype=uint8)

# %%
# adds one more axis to our image
import numpy as np

expanded_image_grayscale = np.expand_dims(image_grayscale, axis= 2)
expanded_image_grayscale.shape
# Out:
# (500, 750, 1)

# %%
expanded_image_grayscale
# Out:
# array([[[245],
#         [245],
#         [245],
#         ...,
#         [245],
#         [245],
#         [245]],
#
#        [[245],
#         [245],
#         [245],
#         ...,
#         [245],
#         [245],
#         [245]],
#
#        [[245],
#         [245],
#         [245],
#         ...,
#         [245],
#         [245],
#         [245]],
#
#        ...,
#
#        [[173],
#         [173],
#         [172],
#         ...,
#         [127],
#         [127],
#         [127]],
#
#        [[171],
#         [171],
#         [171],
#         ...,
#         [125],
#         [125],
#         [124]],
#
#        [[169],
#         [170],
#         [170],
#         ...,
#         [124],
#         [123],
#         [123]]], dtype=uint8)
